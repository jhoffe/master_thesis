# %%
# load jsonl manifest from ../data/emotale/data/manifest.jsonl

import json
from pathlib import Path
from typing import List, Dict, Optional
import os
import pandas as pd

def load_manifest(manifest_path: str) -> List[Dict]:
    """Load a JSONL manifest file."""
    manifest = []
    with open(manifest_path, 'r') as f:
        for line in f:
            manifest.append(json.loads(line))
    return manifest

# make into df
def manifest_to_df(manifest: List[Dict]) -> pd.DataFrame:
    """Convert a list of dictionaries to a pandas DataFrame."""
    return pd.DataFrame(manifest)
# Example usage
manifest = load_manifest('../data/emotale/data/manifest.jsonl')
df = manifest_to_df(manifest)

# %%
df.head()
# Out:
#                                       audio_filepath  duration  \
# 0  /Users/joachimschroderandersson/Desktop/exp/da...  2.673605
# 1  /Users/joachimschroderandersson/Desktop/exp/da...  2.321270
# 2  /Users/joachimschroderandersson/Desktop/exp/da...  2.445624
# 3  /Users/joachimschroderandersson/Desktop/exp/da...  2.642517
# 4  /Users/joachimschroderandersson/Desktop/exp/da...  2.476712
#
#                           text    emotion participant_id age gender  \
# 0  Dugen ligger på køleskabet.    neutral       9be5af06   8      F
# 1  Dugen ligger på køleskabet.      anger       9be5af06   8      F
# 2  Dugen ligger på køleskabet.    sadness       9be5af06   8      F
# 3  Dugen ligger på køleskabet.  happiness       9be5af06   8      F
# 4  Dugen ligger på køleskabet.    boredom       9be5af06   8      F
#
#    samplerate
# 0       44100
# 1       44100
# 2       44100
# 3       44100
# 4       44100

# %%
# sum the durations
total_duration = df['duration'].sum()
print(f"Total duration: {total_duration} seconds")
# in minutes
print(f"Total duration: {total_duration / 60} minutes")
# group by emotion and sum durations
duration_by_emotion = df.groupby('emotion')['duration'].sum()
print("Duration by emotion (minutes):")
print(duration_by_emotion/60)

# group by sentence and sum durations
duration_by_sentence = df.groupby('text')['duration'].sum()
print("Duration by sentence (minutes):")
print(duration_by_sentence/60)

# groupby participant_id and count number of (F)emale and (M)ale
gender_counts = df.groupby('participant_id')['gender'].first().value_counts()
print("Gender counts:")
print(gender_counts)
# Out:
# Total duration: 4358.308480725624 seconds
# Total duration: 72.63847467876039 minutes
# Duration by emotion (minutes):
# emotion
# anger        14.995334
# boredom      13.923819
# happiness    13.462674
# neutral      15.504494
# sadness      14.752153
# Name: duration, dtype: float64
# Duration by sentence (minutes):
# text
# De bar det ovenpå og nu skal de ned igen.                              14.436433
# Det sorte ark papir er placeret deroppe ved siden af tømmerstykket.    23.862447
# Dugen ligger på køleskabet.                                             9.010119
# Om syv timer er det morgen.                                             8.634295
# det vil være på det sted, hvor vi altid opbevarer det.                 16.695181
# Name: duration, dtype: float64
# Gender counts:
# gender
# F    22
# M    22
# Name: count, dtype: int64
